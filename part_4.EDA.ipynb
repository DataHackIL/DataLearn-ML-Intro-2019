# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Some package imports

# %%
# !pip install -U -q datalearn19intro

# %%
import pandas as pd
from datalearn19intro import get_accounts

# %% [markdown]
# ## Reading the data

# %%
acc = get_accounts()

# %%
acc.shape
# Out:
# (1001, 49)

# %%
acc.head()
# Out:
#    account_id  marketing_source                            marketing_referrer  \
# 0     2793496              bing  https://www.bing.com/search?q=basecamp login
# 1     2793497               NaN                                           NaN
# 2     2793498  adwordsverticals                       https://www.google.com/
# 3     2793499               NaN                                           NaN
# 4     2793500    adwordsyoutube                      https://www.youtube.com/
#
#    created_at  plan_id trial_start started_plan_at signup_box_origin  \
# 0  2019-01-01      NaN  2019-01-01             NaN               NaN
# 1  2019-01-01      NaN  2019-01-01             NaN        mobile_app
# 2  2019-01-01      NaN  2019-01-01             NaN               NaN
# 3  2019-01-01      NaN  2019-01-01             NaN        mobile_app
# 4  2019-01-01      NaN  2019-04-04             NaN               NaN
#
#   churn_state churn_date  ...  utm_cluster_id  pricing_version has_domain mrr  \
# 0        none        NaN  ...          orders                3          0 NaN
# 1        none        NaN  ...             NaN                3          0 NaN
# 2        none        NaN  ...           todos                3          0 NaN
# 3        none        NaN  ...             NaN                3          0 NaN
# 4        none        NaN  ...           todos                3          0 NaN
#
#   lead_score  industry.1  team_size  user_goal  user_description sub_industry
# 0          0         NaN        NaN        NaN               NaN          NaN
# 1          0         NaN        NaN        NaN               NaN          NaN
# 2          0       Other          1        NaN               NaN          NaN
# 3          0         NaN        NaN        NaN               NaN          NaN
# 4          0      Design          1        NaN               NaN          NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Summary statistics

# %% [markdown]
# `pandas`' build-it `describe()` method provides with an easy overview of many of the important summary statistics we've mentioned:

# %%
acc.describe()
# Out:
#          account_id    plan_id  churn_reason   time_diff       paying  \
# count  1.001000e+03   15.00000     12.000000  782.000000  1001.000000
# mean   2.793996e+06  230.60000     15.000000    0.671036     0.014985
# std    2.891081e+02   19.82711      4.112067    5.714890     0.121553
# min    2.793496e+06  199.00000      4.000000   -9.000000     0.000000
# 25%    2.793746e+06  230.50000     13.750000   -5.000000     0.000000
# 50%    2.793996e+06  232.00000     16.000000    1.000000     0.000000
# 75%    2.794246e+06  235.00000     18.000000    3.500000     0.000000
# max    2.794496e+06  268.00000     18.000000   13.750000     1.000000
#
#           is_gmail  has_logo  free_users  collection_21_days  trial_period  \
# count  1001.000000    1001.0         0.0         1001.000000        1001.0
# mean      0.679321       1.0         NaN            8.173826          14.0
# std       0.466971       0.0         NaN           80.479698           0.0
# min       0.000000       1.0         NaN            0.000000          14.0
# 25%       0.000000       1.0         NaN            0.000000          14.0
# 50%       1.000000       1.0         NaN            0.000000          14.0
# 75%       1.000000       1.0         NaN            0.000000          14.0
# max       1.000000       1.0         NaN         1428.000000          14.0
#
#        ...  cancellation_on_renewal_date  partner_id  billed_users_count  \
# count  ...                           0.0   57.000000         1001.000000
# mean   ...                           NaN  235.912281            0.068931
# std    ...                           NaN  148.263313            0.685743
# min    ...                           NaN  101.000000            0.000000
# 25%    ...                           NaN  110.000000            0.000000
# 50%    ...                           NaN  199.000000            0.000000
# 75%    ...                           NaN  336.000000            0.000000
# max    ...                           NaN  571.000000           15.000000
#
#        pricing_version   has_domain         mrr   lead_score  user_goal  \
# count           1001.0  1001.000000   33.000000  1001.000000        0.0
# mean               3.0     0.334665   30.030303     0.020979        NaN
# std                0.0     0.472109   35.144776     0.143386        NaN
# min                3.0     0.000000    0.000000     0.000000        NaN
# 25%                3.0     0.000000    0.000000     0.000000        NaN
# 50%                3.0     0.000000   25.000000     0.000000        NaN
# 75%                3.0     1.000000   48.000000     0.000000        NaN
# max                3.0     1.000000  134.000000     1.000000        NaN
#
#        user_description  sub_industry
# count               0.0           0.0
# mean                NaN           NaN
# std                 NaN           NaN
# min                 NaN           NaN
# 25%                 NaN           NaN
# 50%                 NaN           NaN
# 75%                 NaN           NaN
# max                 NaN           NaN
#
# [8 rows x 28 columns]

# %% [markdown]
# This is a great opportunity to learn how to configure the way `pandas` dataframes are displayed:

# %%
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 30)

# %%
acc.describe()
# Out:
#         account_id  plan_id  churn_reason  time_diff   paying  is_gmail  \
# count     1,001.00    15.00         12.00     782.00 1,001.00  1,001.00
# mean  2,793,996.00   230.60         15.00       0.67     0.01      0.68
# std         289.11    19.83          4.11       5.71     0.12      0.47
# min   2,793,496.00   199.00          4.00      -9.00     0.00      0.00
# 25%   2,793,746.00   230.50         13.75      -5.00     0.00      0.00
# 50%   2,793,996.00   232.00         16.00       1.00     0.00      1.00
# 75%   2,794,246.00   235.00         18.00       3.50     0.00      1.00
# max   2,794,496.00   268.00         18.00      13.75     1.00      1.00
#
#        has_logo  free_users  collection_21_days  trial_period  company_size  \
# count  1,001.00        0.00            1,001.00      1,001.00        145.00
# mean       1.00         nan                8.17         14.00      5,676.14
# std        0.00         nan               80.48          0.00     18,341.45
# min        1.00         nan                0.00         14.00          1.00
# 25%        1.00         nan                0.00         14.00         15.00
# 50%        1.00         nan                0.00         14.00        150.00
# 75%        1.00         nan                0.00         14.00      1,600.00
# max        1.00         nan            1,428.00         14.00    123,020.00
#
#        last_upgrade_promotion_start  cs_agent  sales_agent  disabled  \
# count                          0.00      0.00        20.00      8.00
# mean                            nan       nan       291.00      0.88
# std                             nan       nan        78.29      0.35
# min                             nan       nan       209.00      0.00
# 25%                             nan       nan       228.00      1.00
# 50%                             nan       nan       249.50      1.00
# 75%                             nan       nan       345.25      1.00
# max                             nan       nan       409.00      1.00
#
#        disable_promotion  max_team_size  min_team_size  \
# count           1,001.00         737.00         737.00
# mean                0.06          23.11          13.77
# std                 0.24          83.19          61.47
# min                 0.00           0.00           0.00
# 25%                 0.00           1.00           1.00
# 50%                 0.00           5.00           2.00
# 75%                 0.00          10.00           6.00
# max                 1.00         500.00         500.00
#
#        cancellation_on_renewal_date  partner_id  billed_users_count  \
# count                          0.00       57.00            1,001.00
# mean                            nan      235.91                0.07
# std                             nan      148.26                0.69
# min                             nan      101.00                0.00
# 25%                             nan      110.00                0.00
# 50%                             nan      199.00                0.00
# 75%                             nan      336.00                0.00
# max                             nan      571.00               15.00
#
#        pricing_version  has_domain    mrr  lead_score  user_goal  \
# count         1,001.00    1,001.00  33.00    1,001.00       0.00
# mean              3.00        0.33  30.03        0.02        nan
# std               0.00        0.47  35.14        0.14        nan
# min               3.00        0.00   0.00        0.00        nan
# 25%               3.00        0.00   0.00        0.00        nan
# 50%               3.00        0.00  25.00        0.00        nan
# 75%               3.00        1.00  48.00        0.00        nan
# max               3.00        1.00 134.00        1.00        nan
#
#        user_description  sub_industry
# count              0.00          0.00
# mean                nan           nan
# std                 nan           nan
# min                 nan           nan
# 25%                 nan           nan
# 50%                 nan           nan
# 75%                 nan           nan
# max                 nan           nan

# %%
acc.nunique()
# Out:
# account_id                      1001
# marketing_source                  25
# marketing_referrer               152
# created_at                         1
# plan_id                           10
# trial_start                       54
# started_plan_at                   15
# signup_box_origin                  6
# churn_state                        2
# churn_date                         2
# churn_reason                       4
# time_diff                         27
# region                           249
# country                           70
# subscription_started_at           19
# paying                             2
# is_gmail                           2
# has_logo                           1
# free_users                         0
# marketing_banner                  68
# device                             3
# os                                 6
# browser                            7
# collection_21_days                17
# trial_period                       1
# company_size                      82
# next_charge_date                  15
# last_upgrade_promotion_start       0
# cs_agent                           0
# sales_agent                       10
# disabled                           2
# payment_currency                   5
# disable_promotion                  2
# max_team_size                      9
# min_team_size                     10
# cancellation_on_renewal_date       0
# partner_id                        22
# industry                          28
# billed_users_count                 8
# utm_cluster_id                    15
# pricing_version                    1
# has_domain                         2
# mrr                               14
# lead_score                         2
# industry.1                        28
# team_size                         15
# user_goal                          0
# user_description                   0
# sub_industry                       0
# dtype: int64

# %%
acc.isna().sum()
# Out:
# account_id                         0
# marketing_source                 409
# marketing_referrer               271
# created_at                         0
# plan_id                          986
# trial_start                        0
# started_plan_at                  986
# signup_box_origin                739
# churn_state                       17
# churn_date                       999
# churn_reason                     989
# time_diff                        219
# region                            77
# country                           22
# subscription_started_at          982
# paying                             0
# is_gmail                           0
# has_logo                           0
# free_users                      1001
# marketing_banner                 785
# device                             0
# os                                 0
# browser                          218
# collection_21_days                 0
# trial_period                       0
# company_size                     856
# next_charge_date                 985
# last_upgrade_promotion_start    1001
# cs_agent                        1001
# sales_agent                      981
# disabled                         993
# payment_currency                   1
# disable_promotion                  0
# max_team_size                    264
# min_team_size                    264
# cancellation_on_renewal_date    1001
# partner_id                       944
# industry                         509
# billed_users_count                 0
# utm_cluster_id                   484
# pricing_version                    0
# has_domain                         0
# mrr                              968
# lead_score                         0
# industry.1                       507
# team_size                        516
# user_goal                       1001
# user_description                1001
# sub_industry                    1001
# dtype: int64

# %%
acc.isna().sum() / len(acc) * 100
# Out:
# account_id                        0.000000
# marketing_source                 40.859141
# marketing_referrer               27.072927
# created_at                        0.000000
# plan_id                          98.501499
# trial_start                       0.000000
# started_plan_at                  98.501499
# signup_box_origin                73.826174
# churn_state                       1.698302
# churn_date                       99.800200
# churn_reason                     98.801199
# time_diff                        21.878122
# region                            7.692308
# country                           2.197802
# subscription_started_at          98.101898
# paying                            0.000000
# is_gmail                          0.000000
# has_logo                          0.000000
# free_users                      100.000000
# marketing_banner                 78.421578
# device                            0.000000
# os                                0.000000
# browser                          21.778222
# collection_21_days                0.000000
# trial_period                      0.000000
# company_size                     85.514486
# next_charge_date                 98.401598
# last_upgrade_promotion_start    100.000000
# cs_agent                        100.000000
# sales_agent                      98.001998
# disabled                         99.200799
# payment_currency                  0.099900
# disable_promotion                 0.000000
# max_team_size                    26.373626
# min_team_size                    26.373626
# cancellation_on_renewal_date    100.000000
# partner_id                       94.305694
# industry                         50.849151
# billed_users_count                0.000000
# utm_cluster_id                   48.351648
# pricing_version                   0.000000
# has_domain                        0.000000
# mrr                              96.703297
# lead_score                        0.000000
# industry.1                       50.649351
# team_size                        51.548452
# user_goal                       100.000000
# user_description                100.000000
# sub_industry                    100.000000
# dtype: float64

# %% [markdown]
# ## Histograms

# %%
# %matplotlib inline

# %% [markdown]
# Histograms can be very telling when used to plot numerical features.
# In this case we can see company is very skewed; a long tail distribution.

# %%
acc.company_size.hist(figsize=(12,8), bins=30)

# %%
acc.company_size[acc.company_size<20000].hist(figsize=(12,8), bins=30)

# %%
acc.sales_agent.hist(figsize=(10,6), bins=30)

# %%
acc.mrr.hist(figsize=(10,6), bins=30)

# %% [markdown]
# ## Bubble plots

# %%
# !pip install -U -q bubble_plot 
from bubble_plot.bubble_plot import bubble_plot

# %%
nona = acc[~acc.company_size.isna()]
bubble_plot(nona,'company_size','lead_score', normalization_by_all=False)

# %%
# is_gmail
nona = acc[~acc.is_gmail.isna()]
bubble_plot(nona,'is_gmail','lead_score', normalization_by_all=False)

# %% [markdown]
# ## Correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # nice visualization package

# %% [markdown]
# Let only use numeric data (although you can check correlation for other types as well).

# %%
numeric_acc = acc.select_dtypes('number')

# %% [markdown]
# And only look at features with at least ~10% non-missing values.

# %%
numeric_acc.columns[numeric_acc.isna().sum() < 900]
# Out:
# Index(['account_id', 'time_diff', 'paying', 'is_gmail', 'has_logo',
#        'collection_21_days', 'trial_period', 'company_size',
#        'disable_promotion', 'max_team_size', 'min_team_size',
#        'billed_users_count', 'pricing_version', 'has_domain', 'lead_score'],
#       dtype='object')

# %%
numeric_acc = numeric_acc[numeric_acc.columns[numeric_acc.isna().sum() < 900]]

# %%
numeric_acc.shape
# Out:
# (1001, 15)

# %% [markdown]
# 15 features left!

# %%
numeric_acc.head(3)
# Out:
#    account_id  time_diff  paying  is_gmail  has_logo  collection_21_days  \
# 0     2793496       11.0       0         1         1                   0
# 1     2793497        NaN       0         1         1                   0
# 2     2793498       -6.0       0         1         1                   0
#
#    trial_period  company_size  disable_promotion  max_team_size  \
# 0            14           NaN                  0            5.0
# 1            14           NaN                  0            5.0
# 2            14           NaN                  0            1.0
#
#    min_team_size  billed_users_count  pricing_version  has_domain  lead_score
# 0            2.0                   0                3           0           0
# 1            2.0                   0                3           0           0
# 2            1.0                   0                3           0           0

# %%
corrmat = numeric_acc.corr()

# %%
f, ax = plt.subplots(figsize =(11, 9)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %% [markdown]
# * Obvoius positive correlations between the # of billed users and (1) the collection in 21 days (probably of fees) (2) being a payed user.
# * Obvious positive correlation between min and max team size.
# * What about `has_domain` - `is_gmail` - `disable_promotion`?
# * is_gmail has some negative correlation with lead_score, our target.
# * Amusing negative correlation between account id the company size; perhaps smaller clients have joined later? We won't use account id anway...

# %% [markdown]
# Let's look at absolute correlations to let them pop a bit more...

# %%
abscorrmat = abs(numeric_acc.corr())

# %%
f, ax = plt.subplots(figsize =(11, 9)) 
sns.heatmap(abscorrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %% [markdown]
# It's easier to see now `lead_score` is correlated to a non-negligble degree with several features.

# %% [markdown]
# ## Correlation network

# %%
# !pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.org/simple
# Requirement already satisfied: networkx in /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages (2.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages (from networkx) (4.3.0)

# %%
import numpy as np
import networkx as nx
from community import best_partition
import matplotlib.pyplot as plt

# %%
def corr_network(df, threshold=0):
    C = np.corrcoef(df,rowvar=0)
    A = 1*(C>threshold)
    G = nx.Graph(A)
    G = nx.relabel_nodes(G,dict(zip(G.nodes(),df.columns.values)))
    communities = best_partition(G)

    n = len(set(communities.values()))
    print("{} communities detected for {} features!".format(n, len(df.columns)))
    node_coloring = [communities[node]/n for node in G.nodes()]

    nx.pos = nx.fruchterman_reingold_layout(G, dim=2, k=None, pos=None, fixed=None, iterations=5000, weight='weight', scale=1.0, center=None)

    nx.draw_networkx(G, cmap=plt.get_cmap('jet'), with_labels=True, node_color=node_coloring, font_size=16)
    plt.title('Feature correlation network', fontsize=22)
    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)

# %%
corr_network(numeric_acc)
# Out:
# /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in greater
#   This is separate from the ipykernel package so we can avoid doing imports until
# 15 communities detected for 15 features!
# /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
numeric_acc.columns
# Out:
# Index(['account_id', 'time_diff', 'paying', 'is_gmail', 'has_logo',
#        'collection_21_days', 'trial_period', 'company_size',
#        'disable_promotion', 'max_team_size', 'min_team_size',
#        'billed_users_count', 'pricing_version', 'has_domain', 'lead_score'],
#       dtype='object')

# %%
sub_numeric_acc = numeric_acc[['account_id', 'paying', 'collection_21_days','disable_promotion',
    'billed_users_count', 'has_domain', 'lead_score']]

# %%
corr_network(sub_numeric_acc)
# Out:
# 7 communities detected for 7 features!
# /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
corr_network(sub_numeric_acc, threshold=0.2)
# Out:
# 4 communities detected for 7 features!
# /Users/shaypalachy/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
