# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## Some package imports

# %%
# !git clone https://github.com/DataHackIL/DataLearn-ML-Intro-2019
import DataLearn-ML-Intro-2019/dataloder as dataloader
# Out:
#   File "<ipython-input-6-8f770ba9051d>", line 2
#     import DataLearn-ML-Intro-2019/dataloder as dataloader
#                     ^
# SyntaxError: invalid syntax

# %%
# Data import
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
# from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# ---------------------------------------------------------------------------
# ApplicationDefaultCredentialsError        Traceback (most recent call last)
# <ipython-input-4-0002398c8ba7> in <module>
#       3 # auth.authenticate_user()
#       4 gauth = GoogleAuth()
# ----> 5 gauth.credentials = GoogleCredentials.get_application_default()
#       6 drive = GoogleDrive(gauth)
#
# ~/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/oauth2client/client.py in get_application_default()
#    1269                                                 fail to be retrieved.
#    1270         """
# -> 1271         return GoogleCredentials._get_implicit_credentials()
#    1272
#    1273     @staticmethod
#
# ~/.pyenv/versions/3.6.5/envs/py3/lib/python3.6/site-packages/oauth2client/client.py in _get_implicit_credentials(cls)
#    1259
#    1260         # If no credentials, fail.
# -> 1261         raise ApplicationDefaultCredentialsError(ADC_HELP_MSG)
#    1262
#    1263     @staticmethod
#
# ApplicationDefaultCredentialsError: The Application Default Credentials are not available. They are available if running in Google Compute Engine. Otherwise, the environment variable GOOGLE_APPLICATION_CREDENTIALS must be defined pointing to a file defining the credentials. See https://developers.google.com/accounts/docs/application-default-credentials for more information.

# %% [markdown]
# ## Reading the data

# %%
accounts_file_id = '1SFFGL_FIq3-l6CP9MTe9ueuLRMz_tvrw' # you can see it with "get sherable link"
downloaded = drive.CreateFile({'id': accounts_file_id})
downloaded.GetContentFile('accounts.csv')  
accounts = pd.read_csv('accounts.csv')
accounts.head()
# Out:
#    account_id  marketing_source  ... user_description sub_industry
# 0     2793496              bing  ...              NaN          NaN
# 1     2793497               NaN  ...              NaN          NaN
# 2     2793498  adwordsverticals  ...              NaN          NaN
# 3     2793499               NaN  ...              NaN          NaN
# 4     2793500    adwordsyoutube  ...              NaN          NaN
#
# [5 rows x 49 columns]

# %%
from dataloader import get_accounts

# %%
accounts = get_accounts()

# %%
len(accounts.columns)
# Out:
# 49

# %%
accounts.head()
# Out:
#    account_id  marketing_source                            marketing_referrer  \
# 0     2793496              bing  https://www.bing.com/search?q=basecamp login
# 1     2793497               NaN                                           NaN
# 2     2793498  adwordsverticals                       https://www.google.com/
# 3     2793499               NaN                                           NaN
# 4     2793500    adwordsyoutube                      https://www.youtube.com/
#
#    created_at  plan_id trial_start started_plan_at signup_box_origin  \
# 0  2019-01-01      NaN  2019-01-01             NaN               NaN
# 1  2019-01-01      NaN  2019-01-01             NaN        mobile_app
# 2  2019-01-01      NaN  2019-01-01             NaN               NaN
# 3  2019-01-01      NaN  2019-01-01             NaN        mobile_app
# 4  2019-01-01      NaN  2019-04-04             NaN               NaN
#
#   churn_state churn_date  ...  utm_cluster_id  pricing_version has_domain mrr  \
# 0        none        NaN  ...          orders                3          0 NaN
# 1        none        NaN  ...             NaN                3          0 NaN
# 2        none        NaN  ...           todos                3          0 NaN
# 3        none        NaN  ...             NaN                3          0 NaN
# 4        none        NaN  ...           todos                3          0 NaN
#
#   lead_score  industry.1  team_size  user_goal  user_description sub_industry
# 0          0         NaN        NaN        NaN               NaN          NaN
# 1          0         NaN        NaN        NaN               NaN          NaN
# 2          0       Other          1        NaN               NaN          NaN
# 3          0         NaN        NaN        NaN               NaN          NaN
# 4          0      Design          1        NaN               NaN          NaN
#
# [5 rows x 49 columns]
